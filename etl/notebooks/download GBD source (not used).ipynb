# %%
from ddf_utils.factory import ihme as m

# %%
md = m.load_metadata()

# %%
md['age']
# Out:
#      age_id              name short_name   sort  plot       type
# 1         1           Under 5         <5     22     0  aggregate
# 10       10          25 to 29         25     10     1   specific
# 11       11          30 to 34         30     11     1   specific
# 12       12          35 to 39         35     12     1   specific
# 13       13          40 to 44         40     13     1   specific
# 14       14          45 to 49         45     14     1   specific
# 15       15          50 to 54         50     15     1   specific
# 155     155          15 to 60       None      7     1   specific
# 158     158         <20 years        <20  10000     1  aggregate
# 159     159          10 to 24      10-24  10000     1  aggregate
# 16       16          55 to 59         55     16     1   specific
# 162     162          10 to 19       None  10000     0   specific
# 169     169          10 to 54       None  10000     0  aggregate
# ...

# %%
md['measure']
# Out:
#     measure_id  sort                                             name  \
# 1            1     1                                           Deaths
# 2            2     4           DALYs (Disability-Adjusted Life Years)
# 25          25    26                         Maternal mortality ratio
# 26          26    28                                  Life expectancy
# 27          27    27                             Probability of death
# 28          28    29                   HALE (Healthy life expectancy)
# 29          29    21                           Summary exposure value
# 3            3     3               YLDs (Years Lived with Disability)
# 4            4     2                        YLLs (Years of Life Lost)
# 43          43    43  HAQ Index (Healthcare Access and Quality Index)
# 5            5     5                                       Prevalence
# 6            6     6                                        Incidence
#
#     short_name
# 1       Deaths
# 2        DALYs
# ...

# %%
md['sex']
# Out:
#    sex_id    name       label
# 1       1    Male       Males
# 2       2  Female     Females
# 3       3    Both  Both sexes

# %%
year = list(range(1990, 2017))
location = [10, 101, 102, 105, 106, 107, 108, 109, 11, 110, 111,
            112, 113, 114, 115, 116, 117, 118, 119, 12, 121, 122,
            123, 125, 126, 127, 128, 129, 13, 130, 131, 132, 133,
            135, 136, 139, 14, 140, 141, 142, 143, 144, 145, 146,
            147, 148, 149, 15, 150, 151, 152, 153, 154, 155, 156,
            157, 16, 160, 161, 162, 163, 164, 165, 168, 169, 17,
            170, 171, 172, 173, 175, 176, 177, 178, 179, 18, 180,
            181, 182, 183, 184, 185, 186, 187, 189, 19, 190, 191,
            193, 194, 195, 196, 197, 198, 20, 200, 201, 202, 203,
            204, 205, 206, 207, 208, 209, 210, 211, 212, 213,
            214, 215, 216, 217, 218, 22, 23, 24, 25, 26, 27, 28,
            29, 298, 30, 305, 33, 34, 349, 35, 351, 36, 37, 376,
            38, 385, 39, 40, 41, 43, 435, 44, 45, 46, 47, 48, 49,
            50, 51, 52, 522, 53, 54, 55, 57, 58, 59, 6, 60, 61,
            62, 63, 66, 67, 68, 69, 7, 71, 72, 74, 75, 76, 77,
            78, 79, 8, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89,
            90, 91, 92, 93, 94, 95, 97, 98, 99]

# only death rate
measure = 1
metric = [1]
sex = [1, 2, 3]

# contains under 5 and EN/LN/PN, 80 plus and 80-85 etc, need to remove some
age = [*list(range(1, 22)), 30, 31, 32, 235]

# %%
version = 227
context = ['cause']

# %%
m.bulk_download('../source', version, context, year=year,
                location=location, age=age, measure=measure,
                metric=metric, sex=sex,
                email="prairy.long@gmail.com")
# Out:
# working on https://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1
# check status as http://ghdx.healthdata.org/gbd-results-tool/result/e6a5e7e66817551c962f0cb28088dbc1
# available downloads:
# http://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1_files/IHME-GBD_2016_DATA-e6a5e7e6-1.zip
# http://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1_files/IHME-GBD_2016_DATA-e6a5e7e6-2.zip
# http://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1_files/IHME-GBD_2016_DATA-e6a5e7e6-3.zip
# http://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1_files/IHME-GBD_2016_DATA-e6a5e7e6-4.zip
# http://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1_files/IHME-GBD_2016_DATA-e6a5e7e6-5.zip
# http://s3.healthdata.org/gbd-api-2016-production/e6a5e7e66817551c962f0cb28088dbc1_files/IHME-GBD_2016_DATA-e6a5e7e6-6.zip
# ...
